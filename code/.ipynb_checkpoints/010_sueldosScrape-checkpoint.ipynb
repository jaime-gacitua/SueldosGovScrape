# %% [markdown]
# # Web Scraping Gobierno Transparente Chile
# ##### Exploring wage expenses in the goberment. Public information.

# %% [markdown]
# Beautiful soup did not work. The server time outs when you connect through bsoup.
#
# ## Trying Selenium

# %%
import pandas as pd
import numpy as np
import unicodedata
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException

import csv

import sys
sys.path.append('./lib/')

import functions
from functions import *
from tqdm import tnrange, tqdm_notebook
from unidecode import unidecode

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import lxml.html
import lxml

# %load_ext autoreload

# %autoreload 2
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #  Parameters

# %% [markdown]
# # OPTIONAL Gather data already scraped, before re-run

# %%
df_scraped_1 = pd.read_csv('./output/scraped_data_20170214.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_1.shape)
df_scraped_2 = pd.read_csv('./output/scraped_data_20170212.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_2.shape)
df_scraped_3 = pd.read_csv('./output/scraped_data_20170215.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_3.shape)
df_scraped_4 = pd.read_csv('./output/scraped_data_20170215-1.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_4.shape)
df_scraped_5 = pd.read_csv('./output/scraped_data_20170216.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_5.shape)
df_scraped_6 = pd.read_csv('./output/scraped_data_20170221.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_6.shape)
# Out:
# (44783, 21)
# (25227, 21)
# (50586, 20)
# (3145, 20)
# (36591, 20)
# (15300, 20)

# %%
df_scraped = pd.concat([df_scraped_1, df_scraped_2, df_scraped_3, df_scraped_4, df_scraped_5, df_scraped_6]).drop_duplicates()
df_scraped.shape
# Out:
# (114551, 21)

# %%
df_visited = []

# %%
df_visited_1 = pd.read_csv('./output/log_opened_20170212.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_2 = pd.read_csv('./output/log_opened_20170214.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_3 = pd.read_csv('./output/log_opened_20170215.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_4 = pd.read_csv('./output/log_opened_20170221.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_5 = pd.read_csv('./output/log_opened_20170224.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_6 = pd.read_csv('./output/log_opened_20170225.csv', header=None).ix[:,0].drop_duplicates().tolist()


df_visited = list(set(df_visited_1 + df_visited_2 + df_visited_3 + df_visited_4 + df_visited_5 + df_visited_6))
print(len(df_visited))
print(len(df_visited_1))
print(len(df_visited_2))
print(len(df_visited_3))
print(len(df_visited_4))
print(len(df_visited_5))
print(len(df_visited_6))
# Out:
# 14746
# 168
# 482
# 1797
# 156
# 1031
# 11130

# %% [markdown]
# # Main Scraping Run

# %%
period = '20180113'

output = './output/scraped_data_{}.csv'.format(period)

url = 'http://www.gobiernotransparentechile.cl/'

browser = webdriver.Chrome()
#browser = webdriver.Firefox()

df = getGovernmentData(output, url, browser, 0)
# Out:
# Entities:
# ['http://www.gobiernotransparentechile.cl/directorio/entidad/1', 'http://www.gobiernotransparentechile.cl/directorio/entidad/2', 'http://www.gobiernotransparentechile.cl/directorio/entidad/3', 'http://www.gobiernotransparentechile.cl/directorio/entidad/4', 'http://www.gobiernotransparentechile.cl/directorio/entidad/5', 'http://www.gobiernotransparentechile.cl/directorio/entidad/6', 'http://www.gobiernotransparentechile.cl/directorio/entidad/7', 'http://www.gobiernotransparentechile.cl/directorio/entidad/8', 'http://www.gobiernotransparentechile.cl/directorio/entidad/9', 'http://www.gobiernotransparentechile.cl/directorio/entidad/10', 'http://www.gobiernotransparentechile.cl/directorio/entidad/11', 'http://www.gobiernotransparentechile.cl/directorio/entidad/12', 'http://www.gobiernotransparentechile.cl/directorio/entidad/13', 'http://www.gobiernotransparentechile.cl/directorio/entidad/14', 'http://www.gobiernotransparentechile.cl/directorio/entidad/15', 'http://www.gobiernotransparentechile.cl/directorio/entidad/16', 'http://www.gobiernotransparentechile.cl/directorio/entidad/17', 'http://www.gobiernotransparentechile.cl/directorio/entidad/18', 'http://www.gobiernotransparentechile.cl/directorio/entidad/19', 'http://www.gobiernotransparentechile.cl/directorio/entidad/20', 'http://www.gobiernotransparentechile.cl/directorio/entidad/21', 'http://www.gobiernotransparentechile.cl/directorio/entidad/22', 'http://www.gobiernotransparentechile.cl/directorio/entidad/23', 'http://www.gobiernotransparentechile.cl/directorio/entidad/24', 'http://www.gobiernotransparentechile.cl/directorio/entidad/25', 'http://www.gobiernotransparentechile.cl/directorio/entidad/26', 'http://www.gobiernotransparentechile.cl/directorio/entidad/27']
# A Jupyter Widget
# could not get breadcrumbs from http://www.gobiernotransparentechile.cl/directorio/entidad/1/1/per_planta/Ao-2006?x=0&y=0&page_number=5&sort=id&direction=asc
# could not get breadcrumbs from http://www.gobiernotransparentechile.cl/directorio/entidad/1/1/per_planta/Ao-2006?x=0&y=0&page_number=6&sort=id&direction=asc
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/1/1/per_contrata/Ao-2017
# could not get breadcrumbs from http://www.gobiernotransparentechile.cl/directorio/entidad/1/1/per_contrata/Ao-2017
# A Jupyter Widget
# could not get pagination from http://www.interior.gov.cl/transparenciahistorico/sag/dotacionplanta.html
# could not get breadcrumbs from http://www.interior.gov.cl/transparenciahistorico/sag/dotacionplanta.html
# could not get pagination from http://www.interior.gov.cl/transparenciahistorico/sag/dotacioncontrata.html
# could not get breadcrumbs from http://www.interior.gov.cl/transparenciahistorico/sag/dotacioncontrata.html
# A Jupyter Widget
# could not get pagination from http://www.subdere.gov.cl/transparencia/dotacion_2008.html
# could not get breadcrumbs from http://www.subdere.gov.cl/transparencia/dotacion_2008.html
# could not get pagination from http://www.subdere.gov.cl/transparencia/dotacion_2007.html
# could not get breadcrumbs from http://www.subdere.gov.cl/transparencia/dotacion_2007.html
# could not get pagination from http://www.subdere.gov.cl/transparencia/dotacion_2006.html
# could not get breadcrumbs from http://www.subdere.gov.cl/transparencia/dotacion_2006.html
# could not get pagination from http://www.subdere.gov.cl/transparencia/contrata_2008.html
# could not get breadcrumbs from http://www.subdere.gov.cl/transparencia/contrata_2008.html
# could not get pagination from http://www.subdere.gov.cl/transparencia/contrata_2007.html
# could not get breadcrumbs from http://www.subdere.gov.cl/transparencia/contrata_2007.html
# could not get pagination from http://www.subdere.gov.cl/transparencia/contrata_2006.html
# could not get breadcrumbs from http://www.subdere.gov.cl/transparencia/contrata_2006.html
# A Jupyter Widget
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202017/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/A%C3%B1o%202016/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/Ao-2015
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/Ao-2014
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/Ao-2013
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/Ao-2012
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_planta/Ao-2011
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/343/per_contrata/Ao-2011
# Traceback (most recent call last):
#   File "./lib/functions.py", line 62, in getDepartmentData
#     div_years = browser.find_element_by_class_name("linksIntermedios")
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 555, in find_element_by_class_name
#     return self.find_element(by=By.CLASS_NAME, value=name)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 955, in find_element
#     'value': value})['value']
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 312, in execute
#     self.error_handler.check_response(response)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py", line 237, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"linksIntermedios"}
#   (Session info: chrome=63.0.3239.132)
#   (Driver info: chromedriver=2.35.528157 (4429ca2590d6988c0745c24c8858745aaaec01ef),platform=Mac OS X 10.13.2 x86_64)
# No contract data per_planta in http://www.gobiernotransparentechile.cl/directorio/entidad/2/4
# No contract data per_contrata in http://www.gobiernotransparentechile.cl/directorio/entidad/2/4
# Traceback (most recent call last):
#   File "./lib/functions.py", line 62, in getDepartmentData
#     div_years = browser.find_element_by_class_name("linksIntermedios")
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 555, in find_element_by_class_name
#     return self.find_element(by=By.CLASS_NAME, value=name)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 955, in find_element
#     'value': value})['value']
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 312, in execute
#     self.error_handler.check_response(response)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py", line 237, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"linksIntermedios"}
#   (Session info: chrome=63.0.3239.132)
#   (Driver info: chromedriver=2.35.528157 (4429ca2590d6988c0745c24c8858745aaaec01ef),platform=Mac OS X 10.13.2 x86_64)
# A Jupyter Widget
# A Jupyter Widget
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202017/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202016/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202015/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202014/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202013/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_planta/A%C3%B1o%202012/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_contrata/Ao-2007
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/5/per_contrata/Ao-2006
# A Jupyter Widget
# could not get pagination from http://www.interior.gov.cl/transparenciahistorico/sgi/20/dotacionplanta.html
# could not get breadcrumbs from http://www.interior.gov.cl/transparenciahistorico/sgi/20/dotacionplanta.html
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2017/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2016/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2015/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2014/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2013/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2012/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2011/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2010/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2009/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2009/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2009/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2009/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2009/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2009/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2009/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2009/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_planta/2009/Diciembre
# could not get pagination from http://www.interior.gov.cl/transparenciahistorico/sgi/20/dotacioncontrata.html
# could not get breadcrumbs from http://www.interior.gov.cl/transparenciahistorico/sgi/20/dotacioncontrata.html
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2017/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2017/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2017/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2016/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2015/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2014/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2013/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2012/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2011/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2010/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2009/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2009/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2009/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2009/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2009/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2009/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2009/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2009/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/6/per_contrata/2009/Diciembre
# A Jupyter Widget
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2011/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2011/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2011/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2017
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2016
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2015/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2014/Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/2/345/per_planta/2013/Diciembre
# ...
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202015/%20Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202015/%20Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202015/%20Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Diciembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Noviembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Octubre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Septiembre
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Agosto
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Julio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Junio
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Mayo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Abril
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Marzo
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Febrero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/%20A%C3%B1o%202014/%20Enero
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/-Ao-2013
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/-Ao-2012
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/-Ao-2011
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/117/per_contrata/-Ao-2010
# A Jupyter Widget
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2016
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2015
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2014
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2013
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2012
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2011
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2010
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2009
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2008
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2007
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_planta/Ao-2006
# could not get pagination from http://www.serviciocivil.gob.cl/transparencia/file:///C:/Documents%20and%20Settings/Palvear/Escritorio/index.html
# could not get breadcrumbs from http://www.serviciocivil.gob.cl/transparencia/file:///C:/Documents%20and%20Settings/Palvear/Escritorio/index.html
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_contrata/Ao-2012
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_contrata/Ao-2011
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_contrata/Ao-2010
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_contrata/Ao-2009
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_contrata/Ao-2008
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_contrata/Ao-2007
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/118/per_contrata/Ao-2006
# A Jupyter Widget
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2017
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2016
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2015
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2014
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2013
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2012
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2011
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2010
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2009
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2008
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2007
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_planta/Ao-2006
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2017
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2016
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2015
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2014
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2013
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2012
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2011
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2010
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2009
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2008
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2007
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/119/per_contrata/Ao-2006
# A Jupyter Widget
# could not get pagination from http://www.sii.cl/transparencia/dotacionplanta2008.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/dotacionplanta2008.html
# could not get pagination from http://www.sii.cl/transparencia/dotacionplanta2007.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/dotacionplanta2007.html
# could not get pagination from http://www.sii.cl/transparencia/dotacionplanta2006.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/dotacionplanta2006.html
# could not get pagination from http://www.sii.cl/transparencia/2017/per_planta_nov.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2017/per_planta_nov.html
# could not get pagination from http://www.sii.cl/transparencia/2016/per_planta_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2016/per_planta_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2015/per_planta_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2015/per_planta_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2014/per_planta_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2014/per_planta_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2013/per_planta_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2013/per_planta_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2012/per_planta_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2012/per_planta_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2011/per_planta_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2011/per_planta_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2010/per_planta_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2010/per_planta_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2009/per_planta.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2009/per_planta.html
# could not get pagination from http://www.sii.cl/transparencia/dotacioncontrata2008.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/dotacioncontrata2008.html
# could not get pagination from http://www.sii.cl/transparencia/dotacioncontrata2007.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/dotacioncontrata2007.html
# could not get pagination from http://www.sii.cl/transparencia/dotacioncontrata2006.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/dotacioncontrata2006.html
# could not get pagination from http://www.sii.cl/transparencia/2017/per_contrata_nov.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2017/per_contrata_nov.html
# could not get pagination from http://www.sii.cl/transparencia/2016/per_contrata_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2016/per_contrata_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2015/per_contrata_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2015/per_contrata_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2014/per_contrata_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2014/per_contrata_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2013/per_contrata_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2013/per_contrata_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2012/per_contrata_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2012/per_contrata_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2011/per_contrata_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2011/per_contrata_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2010/per_contrata_abr.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2010/per_contrata_abr.html
# could not get pagination from http://www.sii.cl/transparencia/2009/per_contrata.html
# could not get breadcrumbs from http://www.sii.cl/transparencia/2009/per_contrata.html
# A Jupyter Widget
# Traceback (most recent call last):
#   File "./lib/functions.py", line 62, in getDepartmentData
#     div_years = browser.find_element_by_class_name("linksIntermedios")
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 555, in find_element_by_class_name
#     return self.find_element(by=By.CLASS_NAME, value=name)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 955, in find_element
#     'value': value})['value']
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 312, in execute
#     self.error_handler.check_response(response)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py", line 237, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"linksIntermedios"}
#   (Session info: chrome=63.0.3239.132)
#   (Driver info: chromedriver=2.35.528157 (4429ca2590d6988c0745c24c8858745aaaec01ef),platform=Mac OS X 10.13.2 x86_64)
# No contract data per_planta in http://www.gobiernotransparentechile.cl/directorio/entidad/5/122
# No contract data per_contrata in http://www.gobiernotransparentechile.cl/directorio/entidad/5/122
# Traceback (most recent call last):
#   File "./lib/functions.py", line 62, in getDepartmentData
#     div_years = browser.find_element_by_class_name("linksIntermedios")
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 555, in find_element_by_class_name
#     return self.find_element(by=By.CLASS_NAME, value=name)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 955, in find_element
#     'value': value})['value']
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 312, in execute
#     self.error_handler.check_response(response)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py", line 237, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"linksIntermedios"}
#   (Session info: chrome=63.0.3239.132)
#   (Driver info: chromedriver=2.35.528157 (4429ca2590d6988c0745c24c8858745aaaec01ef),platform=Mac OS X 10.13.2 x86_64)
# A Jupyter Widget
# A Jupyter Widget
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2017
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2016
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2015
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2014
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2013
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2012
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2011
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2010
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2009
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2008
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2007
# could not get pagination from http://www.gobiernotransparentechile.cl/directorio/entidad/5/123/per_planta/Ao-2006

# %% [markdown]
# # Debugging

# %%
browser_debug = webdriver.Chrome()
getTableData2('./output/debugging.csv', 'http://www.gobiernotransparentechile.cl/directorio/entidad/12/167/per_planta/A%C3%B1o%202016/Enero', browser_debug)
