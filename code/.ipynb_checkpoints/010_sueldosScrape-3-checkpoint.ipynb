# %% [markdown]
# # Web Scraping Gobierno Transparente Chile
# ##### Exploring wage expenses in the goberment. Public information.

# %% [markdown]
# Beautiful soup did not work. The server time outs when you connect through bsoup.
#
# ## Trying Selenium

# %%
import pandas as pd
import numpy as np
import unicodedata
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException

import csv

import sys
sys.path.append('./lib/')

import functions
from functions import *
from tqdm import tnrange, tqdm_notebook
from unidecode import unidecode

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import lxml.html
import lxml

# %load_ext autoreload
# %load_ext line_profiler
# %autoreload 2
# Out:
# <style>.container { width:100% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %% [markdown]
# #  Parameters

# %% [markdown]
# # OPTIONAL Gather data already scraped, before re-run

# %%
df_scraped_1 = pd.read_csv('./output/scraped_data_20170214.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_1.shape)
df_scraped_2 = pd.read_csv('./output/scraped_data_20170212.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_2.shape)
df_scraped_3 = pd.read_csv('./output/scraped_data_20170215.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_3.shape)
df_scraped_4 = pd.read_csv('./output/scraped_data_20170215-1.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_4.shape)
df_scraped_5 = pd.read_csv('./output/scraped_data_20170216.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_5.shape)
df_scraped_6 = pd.read_csv('./output/scraped_data_20170221.csv', encoding='latin_1', header=None, index_col=0, low_memory=False)
print(df_scraped_6.shape)
# Out:
# (44783, 21)
# (25227, 21)
# (50586, 20)
# (3145, 20)
# (36591, 20)
# (15300, 20)

# %%
df_scraped = pd.concat([df_scraped_1, df_scraped_2, df_scraped_3, df_scraped_4, df_scraped_5, df_scraped_6]).drop_duplicates()
df_scraped.shape
# Out:
# (114551, 21)

# %%
df_visited = []

# %%
df_visited_1 = pd.read_csv('./output/log_opened_20170212.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_2 = pd.read_csv('./output/log_opened_20170214.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_3 = pd.read_csv('./output/log_opened_20170215.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_4 = pd.read_csv('./output/log_opened_20170221.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_5 = pd.read_csv('./output/log_opened_20170224.csv', header=None).ix[:,0].drop_duplicates().tolist()
df_visited_6 = pd.read_csv('./output/log_opened_20170225.csv', header=None).ix[:,0].drop_duplicates().tolist()


df_visited = list(set(df_visited_1 + df_visited_2 + df_visited_3 + df_visited_4 + df_visited_5 + df_visited_6))
print(len(df_visited))
print(len(df_visited_1))
print(len(df_visited_2))
print(len(df_visited_3))
print(len(df_visited_4))
print(len(df_visited_5))
print(len(df_visited_6))
# Out:
# 14746
# 168
# 482
# 1797
# 156
# 1031
# 11130

# %% [markdown]
# # Main Scraping Run

# %%
global period 
period = '20180417-2'

output = '../data/output/scraped_data_{}.csv'.format(period)

url = 'http://www.gobiernotransparentechile.cl/'


option = webdriver.ChromeOptions()
prefs = {'profile.default_content_setting_values': {'images': 2, 'javascript': 2}}
option.add_experimental_option('prefs', prefs)
browser = webdriver.Chrome(chrome_options = option)
#browser = webdriver.Chrome(chrome_options=options)


#browser = webdriver.Chrome()
#browser = webdriver.Firefox()

df = getGovernmentData(output, url, browser, period, cont=['per_honorarios'], start=20, end=30)
# Out:
# Entities:
# 0.- Presidencia de la República: http://www.gobiernotransparentechile.cl/directorio/entidad/1
# 1.- Ministerio del Interior y Seguridad Pública: http://www.gobiernotransparentechile.cl/directorio/entidad/2
# 2.- Ministerio de Relaciones Exteriores: http://www.gobiernotransparentechile.cl/directorio/entidad/3
# per_honorarios Año 2015
# per_honorarios Año 2014
# per_honorarios Año 2013
# per_honorarios Año 2012
# per_honorarios Año 2011
# per_honorarios Año 2010
# per_honorarios Año 2009
#
# Comisión Chilena de Energía Nuclear (CCHEN)
# No contract data per_honorarios in http://www.gobiernotransparentechile.cl/directorio/entidad/21/270
# Traceback (most recent call last):
#   File "./lib/functions.py", line 109, in getDepartmentData
#     div_years = browser.find_element_by_class_name("linksIntermedios")
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 555, in find_element_by_class_name
#     return self.find_element(by=By.CLASS_NAME, value=name)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 955, in find_element
#     'value': value})['value']
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 312, in execute
#     self.error_handler.check_response(response)
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py", line 237, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"linksIntermedios"}
#   (Session info: chrome=65.0.3325.181)
#   (Driver info: chromedriver=2.35.528157 (4429ca2590d6988c0745c24c8858745aaaec01ef),platform=Mac OS X 10.13.3 x86_64)
# A Jupyter Widget
# Comisión Nacional de Energía (CNE)
# A Jupyter Widget
# per_honorarios Histórico
#
# Consejo Nacional de la Cultura y las Artes
# Consejo Nacional de la Cultura y las Artes
# A Jupyter Widget
# per_honorarios 2010
# per_honorarios 2009
# per_honorarios 2008
# per_honorarios 2007
# per_honorarios 2006
# per_honorarios 2015
# per_honorarios 2014
# per_honorarios 2013
# per_honorarios 2012
# per_honorarios 2011
# per_honorarios 2017
# per_honorarios 2016
#
# Ministerio del Medio Ambiente
# Subsecretaría del Medio Ambiente
# A Jupyter Widget
# per_honorarios Año 2018
# per_honorarios Año 2017
# per_honorarios Año 2016
# per_honorarios Año 2015
# per_honorarios Año 2014
# per_honorarios Año 2013
# per_honorarios Año 2012
# per_honorarios Año 2011
# per_honorarios Año 2010
#
# Servicio Evaluación Ambiental
# A Jupyter Widget
# per_honorarios Año 2017
# per_honorarios Año 2016
# per_honorarios Año 2015
# per_honorarios Año 2014
# per_honorarios Año 2013
# per_honorarios Año 2012
# per_honorarios Año 2011
# per_honorarios Año 2010
#
# Superindencia del Medio Ambiente
# A Jupyter Widget
# per_honorarios Año 2018
# per_honorarios Año 2017
# per_honorarios Año 2016
# per_honorarios Año 2015
# per_honorarios Año 2014
# per_honorarios Año 2013
# per_honorarios Año 2012
# per_honorarios Año 2011
# per_honorarios Año 2010
#
# Consejo de Defensa del Estado
# Consejo de Defensa del Estado
# A Jupyter Widget
# per_honorarios Año 2017
# per_honorarios Año 2016
# per_honorarios Año 2015
# per_honorarios Año 2014
# per_honorarios Año 2013
# per_honorarios Año 2012
# per_honorarios Año 2011
# per_honorarios Año 2010
# per_honorarios Año 2009
# per_honorarios Año 2008
# could not get breadcrumbs from http://www.cde.cl/transparencia/2008/per_honorarios.html
# per_honorarios Año 2007
# could not get breadcrumbs from http://www.cde.cl/transparencia/2007/per_honorarios.html
# per_honorarios Año 2006
# could not get breadcrumbs from http://www.cde.cl/transparencia/2006/per_honorarios.html
#
# Consejo Nacional de Televisión
# Consejo Nacional de Televisión (CNTV)
# A Jupyter Widget
# per_honorarios Año 2018
# per_honorarios Año 2017
# per_honorarios Año 2016
# per_honorarios Año 2015
# per_honorarios Año 2014
# per_honorarios Año 2013
# per_honorarios Año 2012
# per_honorarios Año 2011
# per_honorarios Año 2010
# per_honorarios Año 2009
#
# Ministerio del Deporte
# Subsecretaría del deporte
# A Jupyter Widget
# per_honorarios Año 2015
# per_honorarios Año 2014
# per_honorarios Año 2016
#
# Instituto Nacional del Deporte (CHILEDEPORTES)
# A Jupyter Widget
# per_honorarios Año 2010
# per_honorarios Año 2009
# per_honorarios Año 2008
# per_honorarios Año 2007
# per_honorarios Año 2006
#
# Servicio Electoral (SERVEL)
# Servicio Electoral (SERVEL)
# No contract data per_honorarios in http://www.gobiernotransparentechile.cl/directorio/entidad/27/7
# Traceback (most recent call last):
#   File "./lib/functions.py", line 109, in getDepartmentData
#     div_years = browser.find_element_by_class_name("linksIntermedios")
#   File "/Users/jaime/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line
# 27243       CEBALLO            MARCELO FELIPE
# 27244      DIMARQUE          DANILO FRANCISCO
# 27245       BRICEÑO                    MANUEL
# 27246         VARAS            FELIPE ENRIQUE
# 27247       PIZARRO              LUIS EDUARDO
# 27248         BARRA             LUIS SANTIAGO
# 27249        CUADRA               JOSUE ELIAS
# 27250        JUAREZ            CLAUDIO ANDRES
# 27251       CACERES              LUIS OSVALDO
# 27252        ZUÑIGA         ALEJANDRO ESTEBAN
# 27253       ESTRADA            CARLOS ESTEBAN
#
#                                                       8   \
# 0      Apoyar el desarrollo de un programa de generac...
# 1      Asistir y actuar como nexo entre la División d...
# 2      Apoyar en el levantamiento y actualización de ...
# 3      Asistir y sensibilizar a la cuidadanía en el c...
# 4      Apoyar en la administración de la Mesa de Ayud...
# 5      Asesorar estratégicamente a Gabinete Ministeri...
# 6      Proporcionar apoyo técnico y estrategicamente ...
# 7      Asistir técnicamente al equipo, cliente intern...
# 8      Asesorar en la implementación de la Agenda de ...
# 9      Apoyar y cubrir eventos de la Secretaría Regio...
# 10     asesorar en las especificaciones técnicas de l...
# 11     I.- Asesorar a la Autoridad en los aspectos té...
# 12     Apoyar en el establecimiento de vínculos y coo...
# 13     Apoyar en la planificación, ejecución y evalua...
# 14     Apoyar y realizar un análisis social de la rea...
# 15     Apoyar en el proceso de planificar, organizar ...
# 16     Apoyar y diagnosticar el estado de los sistema...
# 17     Apoyar el proceso de gestión y control adminis...
# 18     Apoyar en la revisión de rendiciones de cuenta...
# 19     • Realizar la difusión de la convocatoria del ...
# 20     Apoyar en la revisión y elaboración de decreto...
# 21     • Apoyar las labores de la Unidad de Personal....
# 22     Apoyar en el seguimiento de los mercados eléct...
# 23     Apoyar en la preparación de informes solicitad...
# 24     apoyar a la División de Acceso y Equidad (DAEE...
# 25     Apoyar en la realización de trabajos en terren...
# 26     • Identificar brechas y necesidades para el de...
# 27     1. Coordinar la Agenda de la Sra. Subsecretari...
# 28     I.- Gestión SocialApoyar y proponer una priori...
# 29     Apoyar y administrar el Programa y rendir cuen...
# ...                                                  ...
# 27224                                            MONITOR
# 27225                                 GESTOR TERRITORIAL
# 27226                               INSTRUCTOR DEPORTIVO
# 27227                                 GESTOR TERRITORIAL
# 27228                                  MONITOR DEPORTIVO
# 27229                                  MONITOR DEPORTIVO
# 27230                                           ASESORÍA
# 27231                                      NUTRICIONISTA
# 27232                                 GESTOR TERRITORIAL
# 27233                                 GESTOR TERRITORIAL
# 27234                                 GESTOR TERRITORIAL
# 27235                                           ASESORÍA
# 27236                                   INSTRUCTOR CAYAK
# 27237                                    MÉDICO CIRUJANO
# 27238                                 ENCARGADO DE AUDIO
# 27239            TÉCNICO ESPECIALISTA TAEKWONDO AVANZADO
# 27240            TÉCNICO ESPECIALISTA TAEKWONDO AVANZADO
# 27241                                           PROFESOR
# 27242                                 GESTOR TERRITORIAL
# 27243                                 GESTOR TERRITORIAL
# 27244                                  MONITOR DEPORTIVO
# 27245                                         ENTRENADOR
# 27246                                ENTRENADOR CICLISMO
# 27247                               TECNICO DE ATLETISMO
# 27248                                            EXPERTO
# 27249                               INSTRUCTOR DEPORTIVO
# 27250                               INSTRUCTOR DEPORTIVO
# 27251                                            MONITOR
# 27252                               INSTRUCTOR DEPORTIVO
# 27253                                 GESTOR TERRITORIAL
#
#                                                       9    10    11     12  \
# 0                             INGENIERA EN CONSTRUCCCION  NaN   XII  Pesos
# 1                             INGENIERO CIVIL INDUSTRIAL  NaN    RM  Pesos
# 2                             INGENIERA CIVIL INDUSTRIAL  NaN    RM  Pesos
# 3                                               GEÓGRAFA  NaN    XV  Pesos
# 4                     TÉCNICO EN ADMINISTRACIÓN DE REDES  NaN    RM  Pesos
# 5                                             PERIODISTA  NaN    RM  Pesos
# 6                        INGENIERO EN RECURSOS NATURALES  NaN    RM  Pesos
# 7                     SECRETARIA EJECUTIVA COMPUTACIONAL  NaN    XV  Pesos
# 8                                             ECONOMISTA  NaN    RM  Pesos
# 9                                             PERIODISTA  NaN   VII  Pesos
# 10                            INGENIERA CIVIL INDUSTRIAL  NaN    RM  Pesos
# 11                                LICENCIADO EN ECONOMÍA  NaN    RM  Pesos
# 12                              INGENIERO CIVIL MECÁNICO  NaN    RM  Pesos
# 13                              INGENIERO CIVIL MECÁNICO  NaN    RM  Pesos
# 14                                      ASISTENTE SOCIAL  NaN    XV  Pesos
# 15                                   INGENIERA AMBIENTAL  NaN  VIII  Pesos
# 16                                  TÉCNICO ELECTRICISTA  NaN    RM  Pesos
# 17                    EGRESADA DE ADMINISTRACIÓN PÚBLICA  NaN    RM  Pesos
# 18                                ADMINISTRADORA PÚBLICA  NaN    RM  Pesos
# 19                      INGENIERO CIVIL EN OBRAS CIVILES  NaN    XI  Pesos
# 20                          INGENIERO CIVIL ELECTRICISTA  NaN    RM  Pesos
# 21                                 ADMINISTRADOR PUBLICO  NaN    RM  Pesos
# 22                                   INGENIERO COMERCIAL  NaN    RM  Pesos
# 23                                   INGENIERA COMERCIAL  NaN    RM  Pesos
# 24                                 ADMINISTRADOR PUBLICO  NaN    RM  Pesos
# 25               EGRESADO DE INGENIERÍA CIVIL INDUSTRIAL  NaN    RM  Pesos
# 26                             INGENIERA CIVIL INDUSTRAL  NaN    RM  Pesos
# 27                                            PERIODISTA  NaN    RM  Pesos
# 28                                           ANTROPÓLOGO  NaN    RM  Pesos
# 29                                 INGENIERO AERONÁUTICO  NaN   XII  Pesos
# ...                                                  ...  ...   ...    ...
# 27224                                  TECNICO DEPORTIVO  NaN    VI  Pesos
# 27225                       PROFESOR DE EDUCACION FISICA  NaN    VI  Pesos
# 27226                    TECNICO DEPORTIVO UNIVERSITARIO  NaN     X  Pesos
# 27227                      PROFESORA DE EDUCACION FISICA  NaN   VII  Pesos
# 27228                         ESTUDIANTE PED. ED. FISICA  NaN   VII  Pesos
# 27229                         ESTUDIANTE PED. ED. FISICA  NaN   VII  Pesos
# 27230                       PROFESOR DE EDUCACIÓN FÍSICA  NaN    RM  Pesos
# 27231                                      NUTRICIONISTA  NaN     I  Pesos
# 24     1150000   Si  01/08/2017  31/10/2017
# 25     2442020   Si  01/01/2017  31/12/2017
# 26      690000   Si  11/10/2017  31/12/2017
# 27     4500000   Si  23/10/2017  31/12/2017
# 28         NaN   Si  06/02/2017  30/03/2017
# 29     3612000   Si  01/01/2017  31/12/2017
# ...        ...  ...         ...         ...
# 27224   590000  NaN  16/01/2017  17/02/2017
# 27225   861720   Sí  01/01/2017  30/06/2017
# 27226   112000   Sí  09/01/2017  28/02/2017
# 27227   833856   Sí  01/01/2017  31/12/2017
# 27228   590000   Sí  16/01/2017  15/02/2017
# 27229   590000   Sí  16/01/2017  15/02/2017
# 27230  1548000   Sí  01/01/2017  31/12/2017
# 27231   570000   Sí  01/01/2017  31/10/2017
# 27232   942667   Sí  01/01/2017  31/12/2017
# 27233  1683382  NaN  01/01/2017  31/12/2017
# 27234   942667   Sí  01/01/2017  31/12/2017
# 27235  1741500   Sí  01/01/2017  31/12/2017
# 27236   224000  NaN  16/01/2017  16/03/2017
# 27237  1640969   Sí  01/01/2017  31/12/2017
# 27238    91710   SI  01/01/2017  31/12/2017
# 27239   710000   Sí  01/01/2017  31/12/2017
# 27240   710000   Sí  01/01/2017  31/12/2017
# 27241   850000  NaN  16/01/2017  17/02/2017
# 27242   916416   Sí  01/01/2017  30/06/2017
# 27243   835000   Sí  01/01/2017  31/12/2017
# 27244   291200   Sí  20/02/2017  20/12/2017
# 27245   710000   Sí  01/01/2017  31/12/2017
# 27246   360000   Sí  01/01/2017  31/12/2017
# 27247   710000   Sí  01/01/2017  31/12/2017
# 27248  1294023   Sí  01/01/2017  31/12/2017
# 27249   288000   Sí  24/01/2017  02/03/2017
# 27250   112000  NaN  10/01/2017  17/02/2017
# 27251   590000  NaN  16/01/2017  17/02/2017
# 27252   224000   SI  17/01/2017  03/02/2017
# 27253   861720   Sí  01/01/2017  31/03/2017
#
#                                                       17  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Renuncia voluntaria a contar del 31 octubre de...
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8      Renuncia voluntaria a contar del 19 de abril d...
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12     Renuncia voluntaria a contar del 13 de septiem...
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18     Renuncia voluntaria a contar del 30 de septiem...
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28     Renuncia voluntaria a contar del 01 de abril d...
# 29                                                   NaN
# ...                                                  ...
# 27224                                                NaN
# 27225                                                NaN
# 27226                                                NaN
# 27227                                                NaN
# 27228                                                NaN
# 27229                                                NaN
# 27230                                 Dirección Nacional
# 27231                                                NaN
# 27232                                                NaN
# 27233                     Dos mensualidades de $ 841.691
# 27234                                                NaN
# 27235                                 Dirección Nacional
# 27236                                                NaN
# 27237                                 Dirección Nacional
# 27238                                                NaN
# 27239                                                NaN
# 27240                                                NaN
# 27241                                                NaN
# 27242                                                NaN
# 27243                                                NaN
# 27244                                                NaN
# 27245                                                NaN
# 27246                                                NaN
# 27247                                                NaN
# 27248                                 Dirección Nacional
# 27249                                                NaN
# 27250                                                NaN
# 27251                                                NaN
# 27252                                                NaN
# 27253                                                NaN
#
#                                                       18
# 0      http://www.gobiernotransparentechile.cl/direct...
# 1      http://www.gobiernotransparentechile.cl/direct...
# 2      http://www.gobiernotransparentechile.cl/direct...
