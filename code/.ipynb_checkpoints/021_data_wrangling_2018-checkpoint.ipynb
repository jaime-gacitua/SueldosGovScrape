# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 999

import time
import unicodedata
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, WebDriverException

import datetime
from datetime import timedelta, datetime

import csv
import os

import sys
sys.path.append('./lib/')
from functions import *
from tqdm import tnrange, tqdm_notebook
from unidecode import unidecode

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import lxml.html
import lxml

import glob

# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style("darkgrid")
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Import data

# %%
col_names = ['entity', 'department', 'contract', 'year', 'month', 'group', 'lastn', 'lastn2', 'givenn', 'degree', 
             'qualif', 'position', 'region', 'specials', 'currency', 'salary', 'overt', 'start_date', 'end_date', 'obs', 'url', 'other']
len(col_names)
# Out:
# 22

# %%
file = '../data/output/scraped_data_20180113.csv'
dfscraped = pd.read_csv(file, low_memory=False, names=col_names)

# %%
dfscraped['filename'] = file

# %%
dfscraped.filename.value_counts()
# Out:
# ../data/output/scraped_data_20180113.csv    906540
# Name: filename, dtype: int64

# %%
dfscraped.columns
# Out:
# Index(['entity', 'department', 'contract', 'year', 'month', 'group', 'lastn',
#        'lastn2', 'givenn', 'degree', 'qualif', 'position', 'region',
#        'specials', 'currency', 'salary', 'overt', 'start_date', 'end_date',
#        'obs', 'url', 'other', 'filename'],
#       dtype='object')

# %%
dfscraped.head()
# Out:
#                         entity                   department  \
# 0  Presidencia de la República  Presidencia de la República
# 1  Presidencia de la República  Presidencia de la República
# 2  Presidencia de la República  Presidencia de la República
# 3  Presidencia de la República  Presidencia de la República
# 4  Presidencia de la República  Presidencia de la República
#
#              contract      year    month                  group     lastn  \
# 0  Dotación de planta  Año 2017  allyear  AUTORIDAD DE GOBIERNO  BACHELET
# 1  Dotación de planta  Año 2017  allyear              DIRECTIVO  SANDOVAL
# 2  Dotación de planta  Año 2017  allyear              DIRECTIVO      VEGA
# 3  Dotación de planta  Año 2017  allyear              DIRECTIVO      VIAL
# 4  Dotación de planta  Año 2017  allyear              DIRECTIVO     BRAVO
#
#       lastn2             givenn degree  \
# 0      JERIA  VERONICA MICHELLE    NaN
# 1  NAVARRETE         OSCAR OMAR    NaN
# 2    SANCHEZ  FRANCISCO GABRIEL    NaN
# 3      REYES      CECILIA BERTA    NaN
# 4   CASTILLO     HECTOR ANTONIO    NaN
#
#                                               qualif  \
# 0                                             MÉDICO
# 1                                            ABOGADO
# 2                                INGENIERO COMERCIAL
# 3  INGENIERO COMERCIAL/DOCTORADO EN DESARROLLO EC...
# 4                        LICENCIA DE ENSEÑANZA MEDIA
#
#                                             position region    specials  \
# 0                         PRESIDENTA DE LA REPÚBLICA     RM  2, 4, 8, 9
# 1  DIRECTOR ADMINISTRATIVO, DIRECCIÓN ADMINISTRATIVA     RM  5, 7, 8, 9
# 2                 JEFATURA, DEPARTAMENTO DE FINANZAS     RM     2, 5, 8
# 3  SUBDIRECTORA ADMINISTRATIVA, SUBDIRECCIÓN ADMI...     RM     2, 5, 8
# 4  JEFATURA, SUBDEPARTAMENTO DE SERVICIOS GENERAL...     RM           1
#
#   currency     salary overt  start_date  end_date                     obs  \
# 0    PESOS  9.920.105    No  11/03/2014  30/11/-1                     NaN
# 1    PESOS  7.765.742    No  01/04/2014  30/11/-1  FUNCIÓN CRÍTICA = 100%
# 2    PESOS  5.267.471    No  09/05/2006  30/11/-1   FUNCIÓN CRÍTICA = 50%
# 3    PESOS  6.295.420    No  14/04/2014  30/11/-1  FUNCIÓN CRÍTICA = 100%
# 4    PESOS  1.939.651   NaN  01/06/1993  30/11/-1                     NaN
#
#                                                  url  other  \
# 0  http://www.gobiernotransparentechile.cl/direct...    NaN
# 1  http://www.gobiernotransparentechile.cl/direct...    NaN
# 2  http://www.gobiernotransparentechile.cl/direct...    NaN
# 3  http://www.gobiernotransparentechile.cl/direct...    NaN
# 4  http://www.gobiernotransparentechile.cl/direct...    NaN
#
#                                    filename
# 0  ../data/output/scraped_data_20180113.csv
# 1  ../data/output/scraped_data_20180113.csv
# 2  ../data/output/scraped_data_20180113.csv
# 3  ../data/output/scraped_data_20180113.csv
# 4  ../data/output/scraped_data_20180113.csv

# %%
dfscraped.entity.value_counts()
# Out:
# Ministerio del Interior y Seguridad Pública        462728
# Ministerio de Hacienda                             277297
# entity                                              49011
# Ministerio de Defensa Nacional                      47022
# Ministerio de Relaciones Exteriores                 25028
# Presidencia de la República                         15936
# Ministerio Secretaría General de la Presidencia     15259
# Ministerio de Economía, Fomento y Turismo            9100
# Ministerio Secretaría General de Gobierno            5159
# Name: entity, dtype: int64

# %%
dfscraped.url.nunique()
# Out:
# 20860

# %% [markdown]
# ## Check detailed people

# %%
dfscraped.loc[(dfscraped['givenn'].str.lower().str.contains('solange paola', na=False)), 'url'].unique()
# Out:
# array([ 'http://www.gobiernotransparentechile.cl/directorio/entidad/2/23/per_contrata/2015/Marzo',
#        'http://www.gobiernotransparentechile.cl/directorio/entidad/2/23/per_contrata/2015/Abril',
#        'http://www.gobiernotransparentechile.cl/directorio/entidad/2/23/per_contrata/2015/Mayo'], dtype=object)

# %%
dfscraped.loc[dfscraped['entity'] == 'entity']
# Out:
#         entity  department       contract  year  month             group  \
# 444572  entity  department  type contract  year  month        Directivo
# 444573  entity  department  type contract  year  month        Directivo
# 444574  entity  department  type contract  year  month        Directivo
# 444575  entity  department  type contract  year  month        Directivo
# 444576  entity  department  type contract  year  month        Directivo
# 444577  entity  department  type contract  year  month        Directivo
# 444578  entity  department  type contract  year  month      Profesional
# 444579  entity  department  type contract  year  month      Profesional
# 444580  entity  department  type contract  year  month      Profesional
# 444581  entity  department  type contract  year  month      Profesional
# 444582  entity  department  type contract  year  month      Profesional
# 444583  entity  department  type contract  year  month      Profesional
# 444584  entity  department  type contract  year  month          Técnico
# 444585  entity  department  type contract  year  month   Administrativo
# 444586  entity  department  type contract  year  month   Administrativo
# 444587  entity  department  type contract  year  month        Directivo
# 444588  entity  department  type contract  year  month        Directivo
# 444589  entity  department  type contract  year  month        Directivo
# 444590  entity  department  type contract  year  month        Directivo
# 444591  entity  department  type contract  year  month      Profesional
# 444592  entity  department  type contract  year  month      Profesional
# 444593  entity  department  type contract  year  month      Profesional
# 444594  entity  department  type contract  year  month      Profesional
# 444595  entity  department  type contract  year  month      Profesional
# 444596  entity  department  type contract  year  month      Profesional
# 444597  entity  department  type contract  year  month          Técnico
# 444598  entity  department  type contract  year  month   Administrativo
# 444599  entity  department  type contract  year  month   Administrativo
# 444600  entity  department  type contract  year  month        Directivo
# 444601  entity  department  type contract  year  month        Directivo
# ...        ...         ...            ...   ...    ...               ...
# 898365  entity  department  type contract  year  month   Administrativo
# 898366  entity  department  type contract  year  month   Administrativo
# 898367  entity  department  type contract  year  month   Administrativo
# 898368  entity  department  type contract  year  month   Administrativo
# 898369  entity  department  type contract  year  month      Profesional
# 898370  entity  department  type contract  year  month      Profesional
# 898371  entity  department  type contract  year  month      Profesional
# 898372  entity  department  type contract  year  month   Administrativo
# 898373  entity  department  type contract  year  month      Profesional
# 898374  entity  department  type contract  year  month   Administrativo
# 898375  entity  department  type contract  year  month      Profesional
# 898376  entity  department  type contract  year  month      Profesional
# 898377  entity  department  type contract  year  month      Profesional
# 898378  entity  department  type contract  year  month      Profesional
# 898379  entity  department  type contract  year  month      Profesional
# 898380  entity  department  type contract  year  month      Profesional
# 898381  entity  department  type contract  year  month   Administrativo
# 898382  entity  department  type contract  year  month      Profesional
# 898383  entity  department  type contract  year  month   Administrativo
# 898384  entity  department  type contract  year  month      Profesional
# 898385  entity  department  type contract  year  month   Administrativo
# 898386  entity  department  type contract  year  month         Auxiliar
# 898387  entity  department  type contract  year  month      Profesional
# 898388  entity  department  type contract  year  month      Profesional
# 898389  entity  department  type contract  year  month   Administrativo
# 898390  entity  department  type contract  year  month      Profesional
# 898391  entity  department  type contract  year  month      Profesional
# 898392  entity  department  type contract  year  month      Profesional
# 898393  entity  department  type contract  year  month      Profesional
# 898394  entity  department  type contract  year  month      Profesional
#
#                  lastn        lastn2                      givenn degree  \
# 444572         MENDEZ        RIVERA            SERGIO ALEJANDRO      4
# 444573         NEGRON          RIOS               PATRICIO IVAN      4
# 444574        SEGOVIA        CAMPOS    PATRICIA DE LAS MERCEDES      4
# 444575        TABOADA       MENESES                LUIS ALBERTO      6
# 444576        CORNEJO       SEGOVIA           CLAUDIO ALEJANDRO      7
# 444577         CAMPOS      CALDERON             VIRGINIA JOVITA      9
# 444578       GONZALEZ       MORALES            CRISTIAN ROLANDO      5
# 444579       VILLEGAS     CASTAÑEDA           ANDRELINA ROSARIO      5
# 444580          ROJAS        VARGAS                 JUAN CARLOS      6
# 444581          CAÑON        CONCHA                SONIA IVETTE      8
# 444582         TORRES      PINOCHET             LEONARDO ANDRES      8
# 444583          SILVA        VARGAS          CAROLINA ELIZABETH     11
# 444584          LOPEZ     VELASQUEZ               ALVARO JAVIER     10
# 444585        CORDOVA       NARANJO      JENISE ROSA DEL CARMEN     12
# 444586        BEYZAGA        ZEPEDA                JUAN ORLANDO     15
# 444587         MENDEZ        RIVERA            SERGIO ALEJANDRO      4
# 444588         NEGRON          RIOS               PATRICIO IVAN      4
# 444589        SEGOVIA        CAMPOS    PATRICIA DE LAS MERCEDES      4
# 444590        CORNEJO       SEGOVIA           CLAUDIO ALEJANDRO      7
# 444591       GONZALEZ       MORALES            CRISTIAN ROLANDO      5
# 444592       VILLEGAS     CASTAÑEDA           ANDRELINA ROSARIO      5
# 444593          ROJAS        VARGAS                 JUAN CARLOS      6
# 444594          CAÑON        CONCHA                SONIA IVETTE      8
# 444595         TORRES      PINOCHET             LEONARDO ANDRES      8
# 444596          SILVA        VARGAS          CAROLINA ELIZABETH     11
# 444597          LOPEZ     VELASQUEZ               ALVARO JAVIER     10
# 444598        CORDOVA       NARANJO      JENISE ROSA DEL CARMEN     12
# 444599        BEYZAGA        ZEPEDA                JUAN ORLANDO     15
# 444600        ARRATIA        ARENAS             LORETO FERNANDA      4
# 444601        ESTEFAN        URIZAR                 JUAN MIGUEL      4
# ...                ...           ...                         ...    ...
# 898365           SOTO      SANDOVAL                     CLAUDIO     10
# 898366          TAPIA      BERNALES             ROBERTO ROSAMEL     10
# 898367           TORO    FUENZALIDA               LUIS ROBINSON     10
# 898368         TORRES         ORTIZ                      ALVARO     18
# 898369       TRONCOSO    VALENZUELA              MARCOS ANTONIO     10
# 898370         URBINA         VELIZ                       MAURO      8
# 898371        URIARTE         MUÑOZ                      FELIPE     12
# 898372          URIBE       AGUIRRE              MARCOS EUGENIO     18
# 898373          URIBE          RUIZ               FLOR VERONICA     10
# 898374       VALENCIA       HIDALGO             ALEJANDRA PAOLA     13
# 898375     VALENZUELA        GARCIA                     VICENTE     11
# 898376         VARGAS        VARGAS                     CLAUDIO     12
# 898377           VEGA      GONZALEZ                     PAULINA     10
# 898378          VELEZ         TAPIA                      DAYANA     14
# 898379         VELOSO        ROMERO                      CARLOS     10
# 898380        VENEGAS          ABAD                      ANDRES     10
# 898381        VILCHES         LOPEZ                  EVANGELINA     10
# 898382     VILLARROEL        UGALDE                 JUAN CARLOS     10
# 898383         WINSER     SEPULVEDA               CARMEN GLORIA     15
# 898384         ZABALA       VALLEJO                      ALVARO     10
# 898385        PACHECO         OJIER                    JENNIFER     18
# 898386          ROJAS     SEPULVEDA                       ALIRO     20
# 898387        ZAVANDO       BENITEZ                        MALU      8
# 898388   DE LA FUENTE          TORO                   JOSE LUIS      5
# 898389      GUTIERREZ         MELLA                      PAMELA     10
# 898390           IGOR       VERDEJO                    CAROLINA     14
# 898391       RADEBACH         VARAS                     RICARDO      7
# 898392       RIQUELME       CODOCEO                     TATIANA     14
# 898393          SILVA       CABRERA            MARCELO PATRICIO      6
# 898394         VIENNE       CACERES                    FERNANDO     10
#
#                                                    qualif  \
# 444572                                        ARQUITECTO
# 444573                               INGENIERO COMERCIAL
# 444574                                  CONTADOR AUDITOR
# 444575                  INGENIERO CIVIL EN OBRAS CIVILES
# 444576                    INGENIERO EJECUCION INDUSTRIAL
# 444577           INGENIERO EN ADMINISTRACION DE EMPRESAS
# 444578                               INGENIERO COMERCIAL
# 444579                                  CONTADOR AUDITOR
# 444580                                  CONTADOR AUDITOR
# 444581                                  CONTADOR AUDITOR
# 444582                                 CONSTRUCTOR CIVIL
# 444583                                  CONTADOR AUDITOR
# 444584                          INGENIERO EN INFORMATICA
# 444585                   SECRETARIADO EJECUTIVO BILINGÜE
# 444586               TECNICO PROGRAMACION EN COMPUTACION
# 444587                                        ARQUITECTO
# 444588                               INGENIERO COMERCIAL
# 444589                                  CONTADOR AUDITOR
# 444590                    INGENIERO EJECUCION INDUSTRIAL
# 444591                               INGENIERO COMERCIAL
# 444592                                  CONTADOR AUDITOR
# 444593                                  CONTADOR AUDITOR
# 444594                                  CONTADOR AUDITOR
# 444595                                 CONSTRUCTOR CIVIL
# 444596                                  CONTADOR AUDITOR
# 444597                          INGENIERO EN INFORMATICA
# 444598                   SECRETARIADO EJECUTIVO BILINGÜE
# 444599               TECNICO PROGRAMACION EN COMPUTACION
# 444600                               INGENIERO COMERCIAL
# 444601                         INGENIERO CIVIL ELECTRICO
# ...                                                   ...
# 898365                       Programador de Computadores
# 898366                                    Administrativo
# 898367                                    Administrativo
# 898368                                            Chofer
# 898369                                    Biologo Marino
# 898370                                Ingeniero Pesquero
# 898371                                           Abogado
# 898372                                            Chofer
# 898373                                    Biólogo Marino
# 898374                                        Secretaria
# 898375                         Ingeniero Civil Ambiental
# 898376                                    Biologo Marino
# 898377                                  Contador Auditor
# 898378                  Ingeniero en Pesca y Acuicultura
# 898379                                    Biólogo Marino
# 898380                                Ingeniero Pesquero
# 898381   Secretaria Ejecutiva con mención en computación
# 898382                                    Biólogo Marino
# 898383                                        Secretaria
# 898384                                    Tecnico Marino
# 898385                          Secretaria Computacional
# 898386                                          Auxiliar
# 898387                                Ingeniero Pesquero
# 898388                                         Sociologo
# 898389   Secretaria Ejecutiva con mención en computación
# 898390                                  Contador Auditor
# 898391                                Ingeniero Pesquero
# 898392                         I ngeniero en Acuicultura
# 898393                                Ingeniero Pesquero
# 898394                                Ingeniero Pesquero
#
#                                                  position  region  \
# 444572   JEFE DIVISION DE PLANIFICACION Y DESARROLLO R...     XV
# 444573    JEFE DIVISION DE ANALISIS Y CONTROL DE GESTION      XV
# 444574        JEFA DIVISION DE ADMINISTRACION Y FINANZAS      XV
# 444575   JEFE DE DEPARTAMENTO GESTION E INVERSION REGI...     XV
# 444576         JEFE DEPARTAMENTO DE PRESUPUESTO REGIONAL      XV
# 444577                              UNIDAD DE  AUDITORIA      XV
# 444578                    PROFESIONAL UNIDAD DE ESTUDIOS      XV
# 444579            JEFA(S) DEPTO. CONTABILIDAD Y FINANZAS      XV
# 444580            JEFE (S) DEPTO ADMINISTRACION Y RR.HH.      XV
# 444581                   PROFESIONAL UNIDAD DE AUDITORIA      XV
# 444582   PROFESIONAL DIVISION DE PLANIFICACION Y DESAR...     XV
# 444583                          PROFESIONAL DE TESORERIA      XV
# 444584                     SOPORTE UNIDAD DE INFORMATICA      XV
# 444585   SECRETARIA DIVISION DE PLANIFICACION Y DESARR...     XV
# 444586   ADMINISTRATIVO DIVISION DE ANALISIS Y CONTROL...     XV
# 444587   JEFE DIVISION DE PLANIFICACION Y DESARROLLO R...     XV
# 444588    JEFE DIVISION DE ANALISIS Y CONTROL DE GESTION      XV
# 444589        JEFA DIVISION DE ADMINISTRACION Y FINANZAS      XV
# 444590         JEFE DEPARTAMENTO DE PRESUPUESTO REGIONAL      XV
# 444591                    PROFESIONAL UNIDAD DE ESTUDIOS      XV
# 444592            JEFA(S) DEPTO. CONTABILIDAD Y FINANZAS      XV
# 444593            JEFE (S) DEPTO ADMINISTRACION Y RR.HH.      XV
# 444594                   PROFESIONAL UNIDAD DE AUDITORIA      XV
# 444595   PROFESIONAL DIVISION DE PLANIFICACION Y DESAR...     XV
# 444596                          PROFESIONAL DE TESORERIA      XV
# 444597                     SOPORTE UNIDAD DE INFORMATICA      XV
# 444598   SECRETARIA DIVISION DE PLANIFICACION Y DESARR...     XV
# 444599   ADMINISTRATIVO DIVISION DE ANALISIS Y CONTROL...     XV
# 444600           JEFA DIVISION ADMINISTRACION Y FINANZAS      XV
# 444601   JEFE DE DIVISION DE PLANIFICACION Y DESARROLL...     XV
# ...                                                   ...     ...
# 898365                  Administrativo División Jurídica       V
# 898366                  Administrativo Oficina de Partes       V
# 898367       Administrativo Dirección Zonal Constitucion     VII
# 898368              Auxiliar Departamento Administrativo       V
# 898369      Profesional División Administración Pesquera       V
# 898370       Profesional Departamento Analisis Sectorial       V
# 898371                     Profesional División Jurídica       V
# 898372              Auxiliar Departamento Administrativo       V
# 898373                  Profesional Division Acuicultura       V
# 898374           Secretaria División Desarrollo Pesquero       V
# 898375                  Profesional Division Acuicultura       V
# 898376           Profesional Dirección Zonal Pta. Arenas     XII
# 898377              Profesional Dirección Zonal Coquimbo      IV
# 898378   Profesional Departamento Departamento Coordin...      V
# 898379            Profesional Dirección Zonal Concepcion    VIII
# 898380   Profesional División de Administración Pesquera       V
# 898381                      Secretaria División Jurídica       V
# 898382               Profesional Dirección Zonal Iquique       I
# 898383         Administrativa Dirección Zonal Concepcion    VIII
# 898384                  Profesional Division Acuicultura       V
# 898385      Administrativa  Fondo Investigacion Pesquera       V
# 898386            Auxiliar  Fondo Investigacion Pesquera       V
# 898387         Profesional  Fondo Investigacion Pesquera       V
# 898388        Profesional  Fondo Administracion Pesquera       V
# 898389      Administrativa Fondo Administracion Pesquera       V
# 898390        Profesional  Fondo Administracion Pesquera       V
# 898391        Profesional  Fondo Administracion Pesquera       V
# 898392        Profesional  Fondo Administracion Pesquera       V
# 898393        Profesional  Fondo Administracion Pesquera       V
# 898394        Profesional  Fondo Administracion Pesquera       V
#
#                   specials currency       salary overt    start_date  \
# 444572           (2)  (3)    Pesos    3.090.789     No   01-10-2015
# 444573           (2)  (3)    Pesos    3.051.722     No   01-10-2015
# 444574       (2)  (3) (4)    Pesos    4.645.391     No   01-10-2015
# 898371  ../data/output/scraped_data_20180113.csv
# 898372  ../data/output/scraped_data_20180113.csv
# 898373  ../data/output/scraped_data_20180113.csv
# 898374  ../data/output/scraped_data_20180113.csv
# 898375  ../data/output/scraped_data_20180113.csv
# 898376  ../data/output/scraped_data_20180113.csv
# 898377  ../data/output/scraped_data_20180113.csv
# 898378  ../data/output/scraped_data_20180113.csv
# 898379  ../data/output/scraped_data_20180113.csv
# 898380  ../data/output/scraped_data_20180113.csv
# 898381  ../data/output/scraped_data_20180113.csv
# 898382  ../data/output/scraped_data_20180113.csv
# 898383  ../data/output/scraped_data_20180113.csv
# 898384  ../data/output/scraped_data_20180113.csv
# 898385  ../data/output/scraped_data_20180113.csv
# 898386  ../data/output/scraped_data_20180113.csv
# 898387  ../data/output/scraped_data_20180113.csv
# 898388  ../data/output/scraped_data_20180113.csv
# 898389  ../data/output/scraped_data_20180113.csv
# 898390  ../data/output/scraped_data_20180113.csv
# 898391  ../data/output/scraped_data_20180113.csv
# 898392  ../data/output/scraped_data_20180113.csv
# 898393  ../data/output/scraped_data_20180113.csv
# 898394  ../data/output/scraped_data_20180113.csv
#
# [49011 rows x 23 columns]

# %% [markdown]
# ## Data that was not captured with the right encoding, scrape again

# %%
retake_entity = list(dfscraped[dfscraped.entity.str.contains("b'", na=False)].entity.value_counts().index)
retake_entity = retake_entity + list(dfscraped[dfscraped.entity.str.contains("Ã", na=False)].entity.value_counts().index)
retake_entity = retake_entity + list(dfscraped[dfscraped.entity.str.contains("Ã­", na=False)].entity.value_counts().index)
retake_entity = retake_entity + ['Ministerio del Interior y Seguridad Pblica', 'Presidencia de la Repblica ']

# %%
print('Total Urls', dfscraped.url.nunique())
print('Urls to retake', dfscraped[dfscraped.entity.isin(retake_entity)].url.nunique())
# Out:
# Total Urls 20860
# Urls to retake 0

# %%
retake_entity_urls = []
for u in list(set(dfscraped.loc[dfscraped.entity.isin(retake_entity), 'url'].unique())):
    if str(u) != 'nan':
        if "b'" in u:
            u = u[2:]
        if u[-1] == "'":
            u = u[:len(u)-1]
        retake_entity_urls.append(u)
len(retake_entity_urls)
# Out:
# 0

# %%
retake_entity_urls
# Out:
# []

# %% [markdown]
# ### Open browser and re-scrape data

# %%
output_file = '..data/output/retake_entity_0.csv'

# %%
if not os.path.isfile(output_file):
    browser = webdriver.Chrome()
    for url in retake_entity_urls[0:5]:
        functions.getTableData2(output_file, url, browser)

# %%
try:
    retake_entity_df = pd.read_csv(output_file, encoding='latin1', names=col_names)
except:
    retake_entity_df = pd.DataFrame()

# %%
try:
    retake_entity_df.entity.value_counts()
except:
    pass

# %%
cleanLatin(retake_entity_df)
# Out:
# A Jupyter Widget

# %% [markdown]
# ### Delete the corresponding rows and add the new ones

# %%
retake_entity_df['filename'] = output_file
print(retake_entity_df.shape)
print(dfscraped[dfscraped.entity.isin(retake_entity)].shape)
dfscraped = dfscraped[~dfscraped.entity.isin(retake_entity)]
dfscraped = pd.concat([dfscraped, retake_entity_df])
dfscraped.shape
# Out:
# (0, 1)
# (0, 23)
# (906540, 23)

# %% [markdown]
# # Write or Read clean file

# %%
write_clean_file = True
apply_cleanup_again = False

# %%
if write_clean_file:
    print('Before Processing:', dfscraped.shape)
    columns_dupe = [col for col in dfscraped.columns if not 'filename' in col]
    cleanLatin(dfscraped)
# Out:
# Before Processing: (906540, 23)
# A Jupyter Widget
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# Could not clean column: other
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-dd62cf21d05d> in <module>()
#       4     cleanLatin(dfscraped)
#       5     # Lower case values
# ----> 6     dfscraped1.givenn = dfscraped1.givenn.str.lower()
#       7     dfscraped1.lastn = dfscraped1.lastn.str.lower()
#       8     dfscraped1.lastn2 = dfscraped1.lastn2.str.lower()
#
# NameError: name 'dfscraped1' is not defined

# %%
dfscraped1 = dfscraped
# Lower case values
dfscraped1.givenn = dfscraped1.givenn.str.lower()
dfscraped1.lastn = dfscraped1.lastn.str.lower()
dfscraped1.lastn2 = dfscraped1.lastn2.str.lower()

dfscraped1 = dfscraped.replace(np.nan, -1).drop_duplicates(columns_dupe) # Result used to be 1693274, with no replace()
print('After Processing:', dfscraped1.shape)


# Write file
dfscraped1.to_csv('../data/output/scraped_data_clean.csv', encoding='utf-8', index=False)
# Out:
# After Processing: (693418, 23)

# %%
if not write_clean_file:
    dfscraped1 = pd.read_csv('./output/scraped_data_clean.csv', encoding='latin1', low_memory=False)
    columns_dupe = [col for col in dfscraped1.columns if not 'filename' in col]

if apply_cleanup_again:
    cleanLatin(dfscraped1)
    dfscraped1.drop_duplicates(columns_dupe, inplace=True)

# %% [markdown]
# # Cleaning SENAME

# %%
dfscraped1.entity.value_counts()
# Out:
# Ministerio de Hacienda                             277297
# Ministerio del Interior y Seguridad Pública        250804
# entity                                              48935
# Ministerio de Defensa Nacional                      47022
# Ministerio de Relaciones Exteriores                 25001
# Ministerio Secretaría General de la Presidencia     15204
# Presidencia de la República                         14900
# Ministerio de Economía, Fomento y Turismo            9096
# Ministerio Secretaría General de Gobierno            5159
# Name: entity, dtype: int64

# %%
dfjusticia = dfscraped1.loc[dfscraped1.entity == 'Ministerio del Interior y Seguridad Pública']

# %%
dfjusticia.department.value_counts()
# Out:
# Oficina Nacional de Emergencia (ONEMI)                                                   51822
# Subsecretaría del Interior                                                               20800
# Intendencia Metropolitana                                                                 9979
# Gobierno Regional de La Araucanía                                                         7075
# Gobierno Regional de Los Ríos                                                             6578
# Servicio Nacional para la Prevención y Rehabilitación del Consumo de Drogas y Alcohol     6191
# Gobierno Regional de Valparaíso                                                           5701
# Gobierno Regional de Atacama                                                              5227
# Subsecretaría de Prevención del Delito                                                    4979
# Gobernación de Arica                                                                      2893
# Intendencia de La Araucanía                                                               2863
# Intendencia de Valparaíso                                                                 2793
# Intendencia del Bío Bío                                                                   2773
# Intendencia de O'Higgins                                                                  2682
# Gobernación de Concepción                                                                 2601
# Intendencia de Aysén                                                                      2586
# Gobierno Regional del Maule                                                               2517
# Intendencia de Tarapacá                                                                   2511
# Intendencia de Los Lagos                                                                  2479
# Gobernación de Valparaíso                                                                 2330
# Intendencia de Antofagasta                                                                2301
# Gobernación de Tamarugal                                                                  2280
# Gobernación de Valdivia                                                                   2264
# Intendencia de Coquimbo                                                                   2248
# Intendencia de Magallanes                                                                 2231
# Intendencia Arica y Parinacota                                                            2214
# Gobernación de Magallanes                                                                 2208
# Intendencia del Maule                                                                     2184
# Gobernación de Linares                                                                    2089
# Gobernación de Maipo                                                                      2067
#                                                                                          ...
# Gobernación de Chacabuco                                                                  1590
# Gobernación de Huasco                                                                     1590
# Gobernación de Copiapó                                                                    1578
# Gobernación de Osorno                                                                     1568
# Gobernación de Choapa                                                                     1562
# Gobernación de Limarí                                                                     1534
# Gobernación de El Loa                                                                     1526
# Gobernación de Cauquenes                                                                  1498
# Gobernación de Arauco                                                                     1493
# Gobernación de San Felipe                                                                 1490
# Gobernación de Talagante                                                                  1463
# Gobernación de Palena                                                                     1447
# Gobernación de Última Esperanza                                                           1394
# Gobernación de General Carrera                                                            1393
# Gobernación de Colchagua                                                                  1391
# Gobernación de Marga Marga                                                                1388
# Gobierno Regional Metropolitano de Santiago                                               1351
# Gobernación de Isla de Pascua                                                             1340
# Servicio de Gobierno Interior                                                             1334
# Gobernación de Petorca                                                                    1323
# Gobernación de Parinacota                                                                 1318
# Gobernación de Tierra del Fuego                                                           1283
# Gobernación de Chiloé                                                                     1274
# Gobernación de Chañaral                                                                   1259
# Gobernación de Cardenal Caro                                                              1247
# Gobierno Regional de Los Lagos                                                            1158
# Gobernación de la Antártica Chilena                                                       1126
# Gobierno Regional de Aysén                                                                1117
# Gobernación de Capitán Prat                                                               1076
# Gobierno Regional de O'Higgins                                                             812
# Name: department, Length: 82, dtype: int64

# %%
dfsename = dfjusticia.ix[dfjusticia.department == 'Servicio Nacional de Menores (SENAME)']

# %%
dfsename.groupby(['year', 'month'])['entity'].count()

# %% [markdown]
# ## Year label is a month + it is Known to be from a certain year

# %%
print(dfsename.shape)
# Monthly data, set define months
dfmonths = pd.read_csv('./data/months.csv', dtype={'month2' : str, 'month3' : int})
dfmonths.month3 = dfmonths.month3.astype(int)

months = list(dfmonths.month2.values)

# all the rows that are months we know they are 2016
# mark them as this transformation
dfsename.ix[:,'TmonthIsKnownYear'] = 0
dfsename.ix[dfsename.year.str.lower().isin(months), 'TmonthIsKnownYear'] = 1

# Write Months
dfsename.ix[dfsename.TmonthIsKnownYear == 1, 'month2'] = dfsename.year.str.lower()
dfsename.ix[dfsename.TmonthIsKnownYear == 0, 'month2'] = 'allyear'
dfsename = pd.merge(dfsename, dfmonths, how='left', on='month2')

# Write years
dfsename.ix[:, 'year2'] = dfsename.year.str.extract('( [0-9]*)$', expand=False)
dfsename.ix[dfsename.TmonthIsKnownYear == 1, 'year2'] = 2016
dfsename.year2 = pd.to_numeric(dfsename.year2)

# Include Rows Flag
dfsename['include'] = 1
dfsename.ix[(dfsename.year2 == 2016) & (dfsename.month2 == 'allyear'), 'include'] = 0 # year 2016
dfsename.ix[(dfsename.year == 0) | (dfsename.year == 1), 'include'] = 0 # zeroes and ones

print(dfsename.shape)

# %%
print(dfsename.replace(np.nan, -1).groupby(['include' ,'TmonthIsKnownYear', 'year', 'year2', 'month2', 'month3'])['entity'].count())

# %% [markdown]
# ## Expand yearly data to months. Allows filtering people from months by start_date and end_date.

# %%
print(dfsename.shape)

# Define what df we want to expand to months
cols = [col for col in dfsename.columns if ((col !='month2') and (col != 'month3') )]
df_to_monthly = dfsename.ix[dfsename.month2 == 'allyear', cols]
print(df_to_monthly.shape)

# Keys to mege
df_to_monthly['key'] = 1
dfmonths['key'] = 1

# Generate cartesian product
dfcartesian = pd.merge(df_to_monthly, dfmonths, on='key')
cols2 = [col for col in dfcartesian.columns if col !='key']
dfcartesian = dfcartesian.ix[:,cols2]
print(dfcartesian.shape)

# Remove yearly rows
dfsename = dfsename.ix[dfsename.month2 != 'allyear', :]

# Add monthly rows
dfsename = pd.concat([dfsename, dfcartesian])

# %%
print(dfsename.shape)
print(dfsename.replace(np.nan, -1).groupby(['include' ,'TmonthIsKnownYear', 'year2', 'month3'])['entity'].count().unstack('year2'))

# %%
# Set the datetimeindex index
dfsename['curDate'] = dfsename.year2.map(int).map(str) + '-' + dfsename.month3.map(int).map(str)
dfsename['curDate2'] = pd.to_datetime(dfsename.curDate, format='%Y-%m')
dfsename = dfsename.set_index(pd.DatetimeIndex(dfsename['curDate2']))

# %%
dfsename.ix[dfsename.include == 1].replace(np.nan, -1).groupby('contract').resample('M')['curDate2'].count().unstack('contract').plot()

# %% [markdown]
# Year 2016 looks weird because we have the actual monthly data. The rest of the years are just unparsed yearly data.

# %%
dfsename['start_date'] = dfsename['start_date'].astype(str)
dfsename['end_date'] = dfsename['end_date'].astype(str)

# Fix some guys
dfsename.start_date = dfsename.start_date.str.replace('28/10/201$', '28/10/2010')

# Transform
dfsename['start_date2'] = pd.to_datetime(dfsename['start_date'], format='%d/%m/%Y', errors='coerce')
dfsename['end_date2'] = pd.to_datetime(dfsename['end_date'], format='%d/%m/%Y', errors='coerce')

# %%
print('Start nulls\n', dfsename.ix[pd.isnull(dfsename.start_date2), 'start_date'].value_counts())
print('End nulls\n', dfsename.ix[pd.isnull(dfsename.end_date2), 'end_date'].value_counts())

# %%
# Finished before the report date and not indefinite contract
dfsename.ix[(dfsename.end_date2 < dfsename.curDate2 + timedelta(days=14)) & (dfsename.end_date != 'Indefinido') , 'include'] = 0
# Started after the report date
dfsename.ix[dfsename.start_date2 > dfsename.curDate2 + timedelta(days=14), 'include'] = 0
# Null values
dfsename.ix[dfsename.start_date2 == 'nan', 'include'] = 0
dfsename.ix[dfsename.start_date2 == '', 'include'] = 0

# %%
dfsename.ix[dfsename.include == 1].replace(np.nan, -1).groupby('contract').resample('M')['curDate2'].count().unstack('contract').plot()

# %%
# Percentage of included
included_pct = pd.concat([dfsename.groupby(['include', 'curDate2'])['entity'].count().unstack('include'),
                         dfsename.groupby(['include', 'curDate2'])['entity'].count().unstack('include').sum(axis=1)], axis=1, join='inner')
included_pct.columns = ['no', 'yes', 'total']
included_pct['no_pct'] = included_pct.no / included_pct.total
list(included_pct.ix[included_pct.no_pct > 0.5].index)

# %%
dfsename.ix[(dfsename.curDate2 == '2007-01-01') & (dfsename.include == 0), 'start_date'].value_counts().head()

# %%
# ASSUMPTION: We will assume that the start_date 01/06/2007 is wrong and replace by 01/01/2007
dfsename['TcorrectedDate'] = 0
dfsename.ix[dfsename.start_date == '01/06/2007', 'TcorrectedDate'] = 1
dfsename.ix[dfsename.start_date == '01/06/2007', 'start_date2'] = datetime.strptime('01/01/2007', '%d/%m/%Y')
dfsename.ix[(dfsename.start_date2 <= dfsename.curDate2 + timedelta(days=14)) & 
            ((dfsename.end_date2 >= dfsename.curDate2 + timedelta(days=14)) |
            (dfsename.end_date == 'Indefinido')) , 'include'] = 1

# %%
dfsename.ix[dfsename.include == 1].replace(np.nan, -1).groupby('contract').resample('M')['curDate2'].count().unstack('contract').plot()

# %% [markdown]
# Looking more reasonable, there are some strange spikes at the end of 2007, 2008 and 2009.

# %%
dfsename.ix[dfsename.include == 1].replace(np.nan, -1).groupby('contract').resample('M')['curDate2'].count().unstack('contract')

# %% [markdown]
# ## Can we translate the count into value?

# %%
dfsename['salary2'] = dfsename['salary'].replace('\.', '', regex=True)
dfsename.salary2 = dfsename.salary2.astype(float)
dfsename.salary2.value_counts().head()

# %% [markdown]
# * There are too many zeroes, checking.
# * There are some values that are far too popular, checking source too

# %%
dfsename.ix[dfsename.salary2 == 0].groupby(['curDate2'])['entity'].count().sort_index()

# %%
dfsename.ix[(dfsename.salary2 == 0) & (dfsename.curDate2 == datetime(year=2014, month=7, day=1)), 'url'].value_counts()

# %% [markdown]
# The zeroes in 2014 and over are because of people who resigned

# %%
dfsename.columns

# %%
dfsename.ix[dfsename.salary2 == 1580920.0].groupby(['curDate2', 'givenn', 'lastn', 'lastn2' ])['entity'].count()

# %% [markdown]
# This popular salary is spread across several people

# %% [markdown]
# ## There seems to be duplicated names. Checking

# %%
dfsename.ix[(dfsename.givenn == 'miguel angel') & (dfsename.include == 1) & (dfsename.curDate2 == datetime(year=2016, month=6, day=1))].to_csv('./output/doublename.csv')#

# %%
dfsename.ix[dfsename.include == 1].groupby(['curDate2', 'givenn', 'lastn', 'lastn2'])['entity'].count().sort_values(ascending=False)

# %%
dfsename.ix[(dfsename.givenn == 'miguel angel') & (dfsename.lastn2 == 'canales') & (dfsename.include == 1) & (dfsename.curDate2 == datetime(year=2016, month=6, day=1))].to_csv('./output/doublename.csv')#

# %%
dfscraped.ix[(dfscraped.givenn.str.lower() == 'miguel angel') & (dfscraped.lastn2.str.lower() == 'canales') & (dfscraped.end_date == 'Indefinido')].to_csv('./output/doublename1.csv')#

# %%
dfscraped.ix[[714977, 1705528]]
